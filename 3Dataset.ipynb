# %% [markdown]
# # Below recreates the plots in Section 3. Dataset

# %%
# %load_ext autoreload
# %autoreload 2
import sys
# Add the parent directory to the system path
sys.path.insert(0, '..')
import matplotlib
from matplotlib.patches import Rectangle
from matplotlib.backends.backend_pgf import FigureCanvasPgf
matplotlib.backend_bases.register_backend('pdf', FigureCanvasPgf)
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'text.latex.preamble': '\\usepackage[dvips]{graphicx}\\usepackage{xfrac}\\usepackage{amssymb}\\usepackage{lmodern}'
})

'''
Each model class should have the functions
.train(data_csv)
.generate(n=5000) 
.gen_to_csv()
'''
# Out:
# '\nEach model class should have the functions\n.train(data_csv)\n.generate(n=5000) \n.gen_to_csv()\n'

# %%
from PY.Plotting import FieldSequencesPlotter
R = FieldSequencesPlotter('RealScapyHeaders.csv', val_set=0.4)
R.self_statistics()
R.plot_all_sequence_lengths()
# Out:
# Diversity Score 589 / 1281
# Example ['ShortEnumField', 'ShortField', 'FieldLenField', 'StrLenField']
# Chi² Statistic: 448059755377428268345107071107072.000, p-value: 0.00000
# /home/rohlex/TowardsGeneratingProtocolsAndPackets/PY/Plotting.py:223: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(fontsize=16)

# %%
STATIC_KEYS = ['ARP', 'ModBusTCP', 'UDP', 'PPPoED', 'EAPOL', 'SCTP', 'VRRP', 'NBNSHeader']
ScapyNames =  {p: [p] for p in STATIC_KEYS} | {'ModBusTCP': ['ModbusADURequest', 'ModbusADUResponse']}
R.plot_entropy_on_numfields(show_texts=ScapyNames)
R.plot_all_field_dist()
